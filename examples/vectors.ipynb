# %%
import os
path = "/home/stefanovjc/Documents/"
os.chdir(path)
# %matplotlib qt
from geompy import *
import random

O = point(0, 0)
O.X.lower = -1
O.X.higher = 18
O.Y.lower = -5

O.X.step = 1
O.Y.step = 1
# Out:
# Monitor: eDP-1
# Width: 1920 pixels
# Height: 1200 pixels
# Width: 340 mm
# Height: 220 mm
#
# geompy

# %%
for j in range(10):
    x0 = random.uniform(3, 6)
    x1 = random.uniform(2, 6)
    y0 = random.uniform(3, 5)
    y1 = -random.uniform(2, 5)
    
    A, B = vector(), vector()
    Ap, Bp = point(x0, y0), point(x1, y1)
    A.points, A.points = O, Ap
    B.points, B.points = O, Bp

    Alength = (Ap.x[0]**2 + Ap.y[0]**2)**.5
    Blength = (Bp.x[0]**2 + Bp.y[0]**2)**.5
    AlengthText = text()
    BlengthText = text()
    AlengthText.name = "A = " + f"{Alength:.2f}"
    BlengthText.name = "A = " + f"{Blength:.2f}"
    AlengthText.x, AlengthText.y = 12, 4
    BlengthText.x, BlengthText.y = 12, -4
    #--------------------------------------------
    
    alpha, beta = angle(), angle()
    alpha.centre = beta.centre = O
    C = point(3, 0, draw = False)
    alpha.color = A.color
    beta.color = B.color
    alpha.points, alpha.points = C, Ap
    beta.points, beta.points = Bp, C
    alpha.radius = 1.2
    sizeA = alpha.size*180/pi
    sizeB = beta.size*180/pi

    AlengthText.color = alpha.color
    BlengthText.color = beta.color
    
    alphaName = text()
    alphaName.color = alpha.color
    alphaName.x, alphaName.y = 3, 1
    alphaName.name = fr"$\alpha = {sizeA:.2f} $"
    
    
    betaName = text()
    betaName.color = beta.color
    betaName.x, betaName.y = 3, -1
    betaName.name = fr"$\alpha = {sizeA:.2f} $"
    betaName.name = fr"$\beta = -{sizeB:.2f}$"
    
    vecAName = text()
    vecAName.x, vecAName.y = x0/2, y0*1.4/2
    vecAName.color = A.color
    vecAName.name = r"$\vec{A}$"
    
    
    vecBName = text()
    vecBName.x, vecBName.y = x1/2, y1*1.4/2
    vecBName.color = B.color
    vecBName.name = r"$\vec{B}$"
    pathFile = "/home/stefanovjc/Documents/vectors" + str(j) + ".png"
    plt.savefig(pathFile)
# Out:
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bffa990>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec910>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed1d0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed590>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec910>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121eda90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed590>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121edd10>)
# ('cx', 6.085377008195407)
# ('cy', -1.519439092178085)
# ('am', 2.6773228951159997)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ecf50>)
# ('cx', 7.793425187615442)
# ('cy', 4.275512193178402)
# ('am', 1.9096100048502214)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec7d0>)
# ('am', 2.6773228951159997)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ecf50>)
# ('cx', 0)
# ('cy', 0)
# ('am', 1.9096100048502214)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec7d0>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ecf50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ece10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ece10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121eda90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec7d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121edd10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121edd10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ece10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ece10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121eda90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068e710>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068da90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068efd0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f390>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068da90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed090>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f390>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f9d0>)
# ('cx', 9.80472944482281)
# ('cy', 4.084962904719786)
# ('am', 1.8851346913181517)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ead0>)
# ('cx', 8.389666360506888)
# ('cy', -2.49492738556686)
# ('am', 0.314579527709615)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068fd90>)
# ('am', 1.8851346913181517)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ead0>)
# ('cx', 0)
# ('cy', 0)
# ('am', 0.314579527709615)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068fd90>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ead0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121eca50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121eca50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed090>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068fd90>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f9d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f9d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121eca50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121eca50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed090>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068e710>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10740190>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d107407d0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10740b90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10740190>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10740b90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741090>)
# ('cx', 5.477561537578891)
# ('cy', -0.229816720338067)
# ('am', 5.871302559710679)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740190>)
# ('cx', 10.299813485486606)
# ('cy', -1.8410307704556201)
# ('am', 2.619115818402081)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741310>)
# ('am', 5.871302559710679)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740190>)
# ('cx', 0)
# ('cy', 0)
# ('am', 2.619115818402081)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741310>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740190>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ed50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ed50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741310>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741090>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741090>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ed50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ed50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d107402d0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741450>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741bd0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741f90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741450>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741f90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742490>)
# ('cx', 0.15072841127785708)
# ('cy', -4.002140329866437)
# ('am', 4.093648001273382)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741810>)
# ('cx', 14.88989305719558)
# ('cy', -0.7255180907671157)
# ('am', 0.9388993123908006)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742710>)
# ('am', 4.093648001273382)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741810>)
# ('cx', 0)
# ('cy', 0)
# ('am', 0.9388993123908006)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742710>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741810>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742710>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742490>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742490>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ee90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741090>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742850>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742fd0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743390>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742850>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741a90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743390>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('cx', 0.6991153404669896)
# ('cy', 4.826938341749937)
# ('am', 2.029753902098085)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('cx', 9.561298560342907)
# ('cy', 2.123604217765151)
# ('am', 5.1157196629796164)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10743b10>)
# ('am', 2.029753902098085)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('cx', 0)
# ('cy', 0)
# ('am', 5.1157196629796164)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10743b10>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741a90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10743b10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ec10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741a90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121eca50>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ecf50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec7d0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec910>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ecf50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed950>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ec910>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed6d0>)
# ('cx', 12.85622813005198)
# ('cy', 1.4520941267527903)
# ('am', 3.7238915740168417)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed810>)
# ('cx', 2.9137261584183296)
# ('cy', -3.4540091238491817)
# ('am', 5.566614100874818)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee710>)
# ('am', 3.7238915740168417)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed810>)
# ('cx', 0)
# ('cy', 0)
# ('am', 5.566614100874818)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee710>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed810>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee490>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee490>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed950>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee710>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed6d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed6d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee490>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee490>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ed950>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f610>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f9d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f390>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068dbd0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f9d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121edd10>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068dbd0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d6d0>)
# ('cx', 14.015800421811045)
# ('cy', 5.3373777977718735)
# ('am', 1.2904000318708206)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f890>)
# ('cx', 1.8138931720720546)
# ('cy', -4.300485820837223)
# ('am', 0.8765777827743104)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d450>)
# ('am', 1.2904000318708206)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f890>)
# ('cx', 0)
# ('cy', 0)
# ('am', 0.8765777827743104)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d450>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f890>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee0d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee0d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121edd10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d450>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d6d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d6d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee0d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d121ee0d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d121edd10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068fb10>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d1d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068cf50>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743d90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068d1d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068da90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743d90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('cx', -0.49836328480798375)
# ('cy', -3.9354313501855236)
# ('am', 5.300195959247092)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742ad0>)
# ('cx', 16.243832479483846)
# ('cy', -4.341296461845573)
# ('am', 3.343630101630951)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('am', 5.300195959247092)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742ad0>)
# ('cx', 0)
# ('cy', 0)
# ('am', 3.343630101630951)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742ad0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f610>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f610>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068da90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f610>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068f610>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068da90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741090>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741a90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740690>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741f90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741a90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068cb90>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741f90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741e50>)
# ('cx', 5.046106872114189)
# ('cy', -4.139723304253201)
# ('am', 1.6426421282774955)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742e90>)
# ('cx', 15.857446760717462)
# ('cy', -4.689460954609457)
# ('am', 4.2270374739026435)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740f50>)
# ('am', 1.6426421282774955)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742e90>)
# ('cx', 0)
# ('cy', 0)
# ('am', 4.2270374739026435)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740f50>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742e90>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ca50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ca50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068cb90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740f50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741e50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741e50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ca50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d1068ca50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d1068cb90>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10742c10>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10740410>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740050>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742710>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10740410>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10741d10>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10742710>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d4bf97620>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743c50>)
# ('cx', 3.4945371415191993)
# ('cy', -4.408169308984821)
# ('am', 1.7588421763626)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740b90>)
# ('cx', 5.7777919583080415)
# ('cy', 5.156058979911538)
# ('am', 4.196258772895885)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10620050>)
# ('am', 1.7588421763626)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740b90>)
# ('cx', 0)
# ('cy', 0)
# ('am', 4.196258772895885)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10620050>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10740b90>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741d10>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10620050>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743c50>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743c50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f3d10743890>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f3d10741d10>)

# %%
O = point(0, 0)
O.X.lower = -10
O.X.higher = 10
O.Y.lower = -1
O.Y.higher = 12

O.X.step = 1
O.Y.step = 1

# %%
#for j in range(10):
j = 10
x0 = random.uniform(3, 6)
x1 = -random.uniform(2, 6)
y0 = random.uniform(3, 5)
y1 = random.uniform(2, 5)

A, B = vector(), vector()
Ap, Bp = point(x0, y0), point(x1, y1)
A.points, A.points = O, Ap
B.points, B.points = O, Bp

Alength = (Ap.x[0]**2 + Ap.y[0]**2)**.5
Blength = (Bp.x[0]**2 + Bp.y[0]**2)**.5
AlengthText = text()
BlengthText = text()
AlengthText.name = "A = " + f"{Alength:.2f}"
BlengthText.name = "A = " + f"{Blength:.2f}"
AlengthText.x, AlengthText.y = 8, 4
BlengthText.x, BlengthText.y = 8, 0
#--------------------------------------------

alpha, beta = angle(), angle()
alpha.centre = beta.centre = O
C = point(3, 0, draw = False)
alpha.color = A.color
beta.color = B.color
alpha.points, alpha.points = C, Ap
beta.points, beta.points = Bp, C
alpha.radius = 1.2
sizeA = alpha.size*180/pi
sizeB = beta.size*180/pi

AlengthText.color = alpha.color
BlengthText.color = beta.color

alphaName = text()
alphaName.color = alpha.color
alphaName.x, alphaName.y = 3, 1
alphaName.name = fr"$\alpha = {sizeA:.2f} $"


betaName = text()
betaName.color = beta.color
betaName.x, betaName.y = 3, -1
betaName.name = fr"$\alpha = {sizeA:.2f} $"
betaName.name = fr"$\beta = -{sizeB:.2f}$"

vecAName = text()
vecAName.x, vecAName.y = x0/2, y0*1.4/2
vecAName.color = A.color
vecAName.name = r"$\vec{A}$"


vecBName = text()
vecBName.x, vecBName.y = x1/2, y1*1.4/2
vecBName.color = B.color
vecBName.name = r"$\vec{B}$"
pathFile = "/home/stefanovjc/Documents/vectors" + str(j) + ".png"
plt.savefig(pathFile)
# Out:
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578769090>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f9578768a50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f957876a0d0>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f957876a490>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f9578768a50>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578702490>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578702490>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f9578703610>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f957876a490>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578702490>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578702490>)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f95787691d0>)
# ('cx', -8.537734228928242)
# ('cy', 10.962298050560705)
# ('am', 2.260762032489683)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f957876a850>)
# ('cx', 2.315553919570741)
# ('cy', 1.589585767526963)
# ('am', 3.037808782389945)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578769d10>)
# ('am', 2.260762032489683)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f957876a850>)
# ('cx', 0)
# ('cy', 0)
# ('am', 3.037808782389945)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578769d10>)
# ('cx', 0)
# ('cy', 0)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f957876a850>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f9578647610>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f9578647610>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578703610>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578769d10>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f95787691d0>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f95787691d0>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578647610>)
# ('cx', 0)
# ('cy', 0)
# ('point1', <geompy.pyFiles.pointFile.point object at 0x7f9578647610>)
# ('point0', <geompy.pyFiles.pointFile.point object at 0x7f9578703610>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 45
#      43 betaName = text()
#      44 betaName.color = beta.color
# ---> 45 betaName.x, betaName.y = 3, -1
#      46 betaName.name = fr"$\alpha = {sizeA:.2f} $"
#      47 betaName.name = fr"$\beta = -{sizeB:.2f}$"
#
# File ~/Documents/geompy/pyFiles/pointFile.py:95, in point.y(self, value)
#      93 self.lims()
#      94 self.onlyDraw()
# ---> 95 self.label(self._name)
#
# File ~/Documents/geompy/pyFiles/_plotSettFile.py:338, in plotSett.label(self, name)
#     335 idx = self.condition_mask()
#     336 data = [self.data[0][idx], self.data[1][idx] ]
# --> 338 random_index = np.random.randint(len(data[0]))
#     339 shift = (settings.xmax - settings.xmin)/40
#     341 self.labCoords[0] = data[0][random_index] + shift
#
# File numpy/random/mtrand.pyx:796, in numpy.random.mtrand.RandomState.randint()
#
# File numpy/random/_bounded_integers.pyx:1334, in numpy.random._bounded_integers._rand_int64()
#
# ValueError: high <= 0
